# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r'C:\Users\acer\OneDrive\Python Project file\Movie+Assignment+Data.csv',encoding='latin-1')

# %% [markdown]
# # # Entire Dataset

# %%
dataset
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %% [markdown]
# # # To Display Top 10 Rows of Dataset

# %%
dataset.head(10)
# Out:
#                         Title  title_year     budget      Gross  \
# 0                  La La Land        2016   30000000  151101803
# 1                    Zootopia        2016  150000000  341268248
# 2                        Lion        2016   12000000   51738905
# 3                     Arrival        2016   47000000  100546139
# 4       Manchester by the Sea        2016    9000000   47695371
# 5          Hell or High Water        2016   12000000   27007844
# 6              Doctor Strange        2016  165000000  232641920
# 7                     Tangled        2010  260000000  200807262
# 8       The Dark Knight Rises        2012  250000000  448130642
# 9  Captain America: Civil War        2016  250000000  407197282
#
#            actor_1_name        actor_2_name          actor_3_name  \
# 0          Ryan Gosling          Emma Stone            Amiée Conn
# 1      Ginnifer Goodwin       Jason Bateman            Idris Elba
# ...

# %% [markdown]
# # #To Display Last 10 Rows of Dataset

# %%
dataset.tail(10)
# Out:
#                                            Title  title_year     budget  \
# 90                                  Nightcrawler        2014    8500000
# 91                                         50/50        2011    8000000
# 92                                  End of Watch        2012    7000000
# 93                            Dallas Buyers Club        2013    5000000
# 94                                       Boyhood        2014    4000000
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name       actor_2_name  \
# 90   32279955           Jake Gyllenhaal   Michael Papajohn
# ...

# %% [markdown]
# # # To check Shape of our Dataset (Like no. of rows and columns)

# %%
dataset.shape       # here using shape attribute
# Out:
# (100, 62)

# %%
print('Number of Rows =>',dataset.shape[0])       # [0] => shows no. of rows 
print ('Number of columns =>',dataset.shape[1])   # [1] => shows no. of columns
# Out:
# Number of Rows => 100
# Number of columns => 62

# %% [markdown]
# # #To get information of our Dataset (Like Total No. of Rows, collumns,Datatype of each cilumn and Memory Allocation

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %% [markdown]
# # # To see the all columns header

# %%
dataset.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
#        'VotesnUS', 'content_rating', 'Country'],
#       dtype='object')

# %% [markdown]
# # #  To check Missing value in our Dataset

# %%
print("Any Missing vlaue =>",dataset.isnull().values.any())
# Out:
# Any Missing vlaue => True

# %%
dataset.isnull().sum().head(20)
# Out:
# Title                      0
# title_year                 0
# budget                     0
# Gross                      0
# actor_1_name               0
# actor_2_name               0
# actor_3_name               0
# actor_1_facebook_likes     0
# actor_2_facebook_likes     1
# actor_3_facebook_likes     2
# IMDb_rating                0
# genre_1                    0
# genre_2                    3
# genre_3                   26
# MetaCritic                 5
# Runtime                    0
# CVotes10                   0
# CVotes09                   0
# CVotes08                   0
# CVotes07                   0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
missing_percentag = dataset.isnull().sum()* 100 /len(dataset)
missing_percentag.head(20)
# Out:
# Title                      0.0
# title_year                 0.0
# budget                     0.0
# Gross                      0.0
# actor_1_name               0.0
# actor_2_name               0.0
# actor_3_name               0.0
# actor_1_facebook_likes     0.0
# actor_2_facebook_likes     1.0
# actor_3_facebook_likes     2.0
# IMDb_rating                0.0
# genre_1                    0.0
# genre_2                    3.0
# genre_3                   26.0
# MetaCritic                 5.0
# Runtime                    0.0
# CVotes10                   0.0
# CVotes09                   0.0
# CVotes08                   0.0
# CVotes07                   0.0
# dtype: float64

# %% [markdown]
# # #  To Drop all the missing values

# %%
dataset.dropna(axis=0, inplace=True)    # Here axis=0 represent rows and axis=1 represent columns
dataset
# Out:
#                                            Title  title_year     budget  \
# 1                                       Zootopia        2016  150000000
# 5                             Hell or High Water        2016   12000000
# 7                                        Tangled        2010  260000000
# 9                     Captain America: Civil War        2016  250000000
# 12                                   Toy Story 3        2010  200000000
# ..                                           ...         ...        ...
# 90                                  Nightcrawler        2014    8500000
# 91                                         50/50        2011    8000000
# 92                                  End of Watch        2012    7000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
#
#         Gross          actor_1_name        actor_2_name         actor_3_name  \
# ...

# %% [markdown]
# # # To check Duplicate Data

# %%
duplicate_data = dataset.duplicated().any()
duplicate_data
# Out:
# False

# %%
print('Are there any duplicate vslues  =>',duplicate_data)
# Out:
# Are there any duplicate vslues  => False

# %%
drop_duplicate = dataset.drop_duplicates()     # To drop duplicate values if any
drop_duplicate.head(40)
# Out:
#                                   Title  title_year     budget      Gross  \
# 1                              Zootopia        2016  150000000  341268248
# 5                    Hell or High Water        2016   12000000   27007844
# 7                               Tangled        2010  260000000  200807262
# 9            Captain America: Civil War        2016  250000000  407197282
# 12                          Toy Story 3        2010  200000000  414984497
# 13                              Skyfall        2012  200000000  304360277
# 14           X-Men: Days of Future Past        2014  200000000  233914986
# 15              Star Trek Into Darkness        2013  190000000  228756232
# 17                     Edge of Tomorrow        2014  178000000  100189501
# 18                           Inside Out        2015  175000000  356454367
# 19              Guardians of the Galaxy        2014  170000000  333130696
# 20  Captain America: The Winter Soldier        2014  170000000  259746958
# ...

# %% [markdown]
# # To See statistic view of Dataset

# %%
dataset.describe()            # dataset.describe(include='all') => to see all categorical &  numerical dataset
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count    68.000000  6.800000e+01  6.800000e+01               68.000000
# mean   2012.882353  9.085588e+07  1.619673e+08            13834.397059
# std       1.881008  7.256085e+07  1.477099e+08            10181.493850
# min    2010.000000  7.000000e+06  1.339152e+06               39.000000
# 25%    2011.000000  2.500000e+07  5.421977e+07             2600.000000
# 50%    2013.000000  6.100000e+07  1.340542e+08            13000.000000
# 75%    2014.000000  1.612500e+08  2.285123e+08            19250.000000
# max    2016.000000  2.600000e+08  9.366622e+08            34000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               68.000000               68.000000    68.000000
# mean              6505.676471             2650.029412     7.870588
# std               7975.249642             5400.709503     0.247410
# ...

# %% [markdown]
# # To Display Title of Movie Having Runtime >= 180 minutes

# %%
dataset.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
#        'VotesnUS', 'content_rating', 'Country'],
#       dtype='object')

# %%
dataset[dataset['Runtime']>=180]['Runtime'],['Title']
# Out:
# (36    180
#  Name: Runtime, dtype: int64,
#  ['Title'])

# %%
dataset[dataset['Runtime']>=180]['Title']
# Out:
# 36    The Wolf of Wall Street
# Name: Title, dtype: object

# %% [markdown]
# # # In which year Highest Average Voting by Male and Female

# %%
dataset.groupby('title_year')['CVotesMale'].mean().sort_values(ascending=False)
# Out:
# title_year
# 2012    356571.000000
# 2010    309029.333333
# 2014    293530.750000
# 2011    240408.181818
# 2013    238611.647059
# 2015    224623.416667
# 2016    186631.444444
# Name: CVotesMale, dtype: float64

# %%
dataset.groupby('title_year')['CVotesFemale'].mean().sort_values(ascending=False)
# Out:
# title_year
# 2012    86421.230769
# 2010    81090.444444
# 2014    66941.650000
# 2011    60497.909091
# 2013    57206.588235
# 2015    42297.250000
# 2016    42154.777778
# Name: CVotesFemale, dtype: float64

# %%
sns.barplot(x='title_year',y='CVotesMale',data=dataset) 
plt.title('male votes by year')
plt.show()

# %%
sns.barplot(x='title_year',y='CVotesFemale',data=dataset)
plt.title('Female votes by year')
plt.show()

# %% [markdown]
# # # In which year The Highest Average rating by Metacritic ?

# %%
dataset.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
#        'VotesnUS', 'content_rating', 'Country'],
#       dtype='object')

# %%
dataset.groupby('title_year')['MetaCritic'].mean().sort_values(ascending=False)
# Out:
# title_year
# 2015    81.833333
# 2013    81.714286
# 2016    79.666667
# 2014    77.600000
# 2012    77.000000
# 2010    75.764706
# 2011    75.181818
# Name: MetaCritic, dtype: float64

# %% [markdown]
# # # To Display Top 10 Lengthy Movie Title and Runtime

# %%
dataset.nlargest(10,'Runtime')[['Title','Runtime']]     # [[put desired columns here]]
# Out:
#                                   Title  Runtime
# 36              The Wolf of Wall Street      180
# 16    The Hobbit: An Unexpected Journey      169
# 26                         Interstellar      169
# 35                     Django Unchained      165
# 94                              Boyhood      165
# 8                 The Dark Knight Rises      164
# 10  The Hobbit: The Desolation of Smaug      161
# 38      The Girl with the Dragon Tattoo      158
# 44                      Les MisÃ©rables      158
# 31                         The Revenant      156

# %%
Top10_lengthy=dataset.nlargest(10,'Runtime')[['Title','Runtime']]\
.set_index('Title')

# %%
Top10_lengthy
# Out:
#                                      Runtime
# Title
# The Wolf of Wall Street                  180
# The Hobbit: An Unexpected Journey        169
# Interstellar                             169
# Django Unchained                         165
# Boyhood                                  165
# The Dark Knight Rises                    164
# The Hobbit: The Desolation of Smaug      161
# The Girl with the Dragon Tattoo          158
# Les MisÃ©rables                          158
# The Revenant                             156

# %%
sns.barplot(x='Runtime',y=Top10_lengthy.index, data=Top10_lengthy)     # using barplot to relation b/w atleast one categorical data and one Numerical data
plt.title('Top10 lengthy movie name with Runtime')
plt.show()

# %% [markdown]
# # # To Display Number of Movie per year

# %%
dataset['title_year'].value_counts().sort_values(ascending=False)
# Out:
# title_year
# 2014    20
# 2010    18
# 2013    17
# 2012    13
# 2015    12
# 2011    11
# 2016     9
# Name: count, dtype: int64

# %%
ax=sns.countplot(x='title_year', data=dataset)
plt.title('Count of Movie per year')

for bar in ax.containers:
    ax.bar_label(bar)
plt.show()

# %% [markdown]
# # # Find Most Popular movie Title(Highest Budget)

# %%
dataset[dataset['budget'].max()==dataset['budget']]['Title']
# Out:
# 7    Tangled
# Name: Title, dtype: object

# %% [markdown]
# # # Display Top 10 Highest Rated Movie Title and Its Actor

# %%
top10_lengthy=dataset.nlargest(10,'IMDb_rating')[['Title','IMDb_rating','actor_1_name']]\
.set_index('Title')

# %%
top10_lengthy
# Out:
#                          IMDb_rating         actor_1_name
# Title
# Inception                        8.8    Leonardo DiCaprio
# Interstellar                     8.6  Matthew McConaughey
# Whiplash                         8.5         J.K. Simmons
# The Dark Knight Rises            8.4            Tom Hardy
# Django Unchained                 8.4    Leonardo DiCaprio
# Toy Story 3                      8.3            Tom Hanks
# La La Land                       8.2         Ryan Gosling
# Inside Out                       8.2          Amy Poehler
# The Wolf of Wall Street          8.2    Leonardo DiCaprio
# Warrior                          8.2            Tom Hardy

# %%
sns.barplot(x='IMDb_rating',y=top10_lengthy.index, data=top10_lengthy,hue='actor_1_name',dodge=False)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)

# %% [markdown]
# # # Display Top 10 Highest Budget movie Titles

# %%
Top_10=dataset.nlargest(10, 'budget')[['Title','budget']].\
set_index('Title')

# %%
Top_10
# Out:
#                                                budget
# Title
# Tangled                                     260000000
# The Dark Knight Rises                       250000000
# Captain America: Civil War                  250000000
# Star Wars: Episode VII - The Force Awakens  245000000
# The Hobbit: The Desolation of Smaug         225000000
# The Avengers                                220000000
# Toy Story 3                                 200000000
# Skyfall                                     200000000
# X-Men: Days of Future Past                  200000000
# Star Trek Into Darkness                     190000000

# %%
sns.barplot(x='budget',y=Top_10.index,data=Top_10)
plt.title('Highest Budget Movie Title')
# Out:
# Text(0.5, 1.0, 'Highest Budget Movie Title')

# %% [markdown]
# # # Display Average Rating of Movie year wise

# %%
dataset.groupby('title_year')['IMDb_rating'].mean().sort_values(ascending=False)
# Out:
# title_year
# 2016    7.944444
# 2014    7.935000
# 2012    7.907692
# 2015    7.900000
# 2013    7.852941
# 2010    7.850000
# 2011    7.790909
# Name: IMDb_rating, dtype: float64

# %% [markdown]
# # # classify Movie Based on Rating (Excellent, Good and Bad)

# %%
def rating(rating):
    if rating>=7.0:
        return "Excellent"
    elif rating>=6.0:
        return 'Good'
    else:
        return 'Average'

# %%
dataset['Rating_category']=dataset['IMDb_rating'].apply(rating)

# %%
dataset.head(10)
# Out:
#                         Title  title_year     budget      Gross  \
# 0                  La La Land        2016   30000000  151101803
# 1                    Zootopia        2016  150000000  341268248
# 2                        Lion        2016   12000000   51738905
# 3                     Arrival        2016   47000000  100546139
# 4       Manchester by the Sea        2016    9000000   47695371
# 5          Hell or High Water        2016   12000000   27007844
# 6              Doctor Strange        2016  165000000  232641920
# 7                     Tangled        2010  260000000  200807262
# 8       The Dark Knight Rises        2012  250000000  448130642
# 9  Captain America: Civil War        2016  250000000  407197282
#
#            actor_1_name        actor_2_name          actor_3_name  \
# 0          Ryan Gosling          Emma Stone            Amiée Conn
# 1      Ginnifer Goodwin       Jason Bateman            Idris Elba
# ...

# %% [markdown]
# # # count Number of Action Movie

# %%
len(dataset[dataset['genre_1'].str.contains('Action',case=False)])
# Out:
# 27

# %% [markdown]
# # # Find unique values from Genre

# %%
dataset['genre_1']
# Out:
# 0        Comedy
# 1     Animation
# 2     Biography
# 3         Drama
# 4         Drama
#         ...
# 95        Drama
# 96        Drama
# 97       Action
# 98    Adventure
# 99       Comedy
# Name: genre_1, Length: 100, dtype: object

# %%
list1=[]
for value in dataset['genre_1']:
    list1.append (value.split(','))

# %%
list1
# Out:
# [['Comedy'],
#  ['Animation'],
#  ['Biography'],
#  ['Drama'],
#  ['Drama'],
#  ['Crime'],
#  ['Action'],
#  ['Animation'],
#  ['Action'],
#  ['Action'],
#  ['Adventure'],
#  ['Action'],
#  ['Animation'],
#  ['Action'],
#  ['Action'],
#  ['Action'],
#  ['Adventure'],
#  ['Action'],
#  ['Animation'],
#  ['Action'],
#  ['Action'],
#  ['Action'],
#  ['Adventure'],
#  ['Animation'],
#  ['Animation'],
#  ['Animation'],
#  ['Adventure'],
#  ['Action'],
#  ['Action'],
#  ['Action'],
#  ['Animation'],
#  ['Adventure'],
#  ['Action'],
#  ['Adventure'],
#  ['Drama'],
#  ['Drama'],
#  ['Biography'],
#  ['Action'],
#  ['Crime'],
#  ['Animation'],
#  ['Mystery'],
#  ['Animation'],
#  ['Action'],
#  ['Crime'],
#  ['Drama'],
#  ['Animation'],
#  ['Action'],
#  ['Action'],
#  ['Biography'],
#  ['Biography'],
#  ['Crime'],
#  ['Action'],
#  ['Action'],
#  ['Biography'],
#  ['Drama'],
#  ['Adventure'],
#  ['Action'],
#  ['Crime'],
#  ['Drama'],
#  ['Action'],
#  ['Action'],
#  ['Biography'],
# ...

# %%
one_d=[]
for item in list1:
    for item1 in item:
        one_d.append(item1)

# %%
one_d
# Out:
# ['Comedy',
#  'Animation',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Action',
#  'Animation',
#  'Action',
#  'Action',
#  'Adventure',
#  'Action',
#  'Animation',
#  'Action',
#  'Action',
#  'Action',
#  'Adventure',
#  'Action',
#  'Animation',
#  'Action',
#  'Action',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Animation',
#  'Animation',
#  'Adventure',
#  'Action',
#  'Action',
#  'Action',
#  'Animation',
#  'Adventure',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Biography',
#  'Action',
#  'Crime',
#  'Animation',
#  'Mystery',
#  'Animation',
#  'Action',
#  'Crime',
#  'Drama',
#  'Animation',
#  'Action',
#  'Action',
#  'Biography',
#  'Biography',
#  'Crime',
#  'Action',
#  'Action',
#  'Biography',
#  'Drama',
#  'Adventure',
#  'Action',
#  'Crime',
#  'Drama',
#  'Action',
#  'Action',
#  'Biography',
#  'Biography',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Biography',
#  'Crime',
# ...

# %%
uni_list=[]
for item in one_d:
    if item not in uni_list:
        uni_list.append(item)

# %%
uni_list
# Out:
# ['Comedy',
#  'Animation',
#  'Biography',
#  'Drama',
#  'Crime',
#  'Action',
#  'Adventure',
#  'Mystery']

# %% [markdown]
# # # How Many Films of Each Genre Were Made

# %%
one_d=[]
for item in list1:
    for item1 in item:
        one_d.append(item1)

# %%
one_d
# Out:
# ['Comedy',
#  'Animation',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Action',
#  'Animation',
#  'Action',
#  'Action',
#  'Adventure',
#  'Action',
#  'Animation',
#  'Action',
#  'Action',
#  'Action',
#  'Adventure',
#  'Action',
#  'Animation',
#  'Action',
#  'Action',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Animation',
#  'Animation',
#  'Adventure',
#  'Action',
#  'Action',
#  'Action',
#  'Animation',
#  'Adventure',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Biography',
#  'Action',
#  'Crime',
#  'Animation',
#  'Mystery',
#  'Animation',
#  'Action',
#  'Crime',
#  'Drama',
#  'Animation',
#  'Action',
#  'Action',
#  'Biography',
#  'Biography',
#  'Crime',
#  'Action',
#  'Action',
#  'Biography',
#  'Drama',
#  'Adventure',
#  'Action',
#  'Crime',
#  'Drama',
#  'Action',
#  'Action',
#  'Biography',
#  'Biography',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Biography',
#  'Crime',
# ...

# %%
from collections import Counter

# %%
Counter(one_d)
# Out:
# Counter({'Action': 27,
#          'Drama': 18,
#          'Biography': 13,
#          'Adventure': 12,
#          'Animation': 11,
#          'Comedy': 9,
#          'Crime': 9,
#          'Mystery': 1})
